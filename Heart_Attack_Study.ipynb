# %% [markdown]
# # Heart Attack Study

# %% [raw]
# We will be analysing a heeart attacks dataset by Zheen hospital in Erbil, Iraq obtained in kaggle

# %%
# Dependences
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split

# %%
# Load the dataset
dataHeartAttacks = pd.read_csv('dataset-heartAttacks-ZheenHospital/Medicaldataset.csv', sep=",")

# The dataset contains 1319 rows
# Print the info on the dataset to check it was imported correctly
dataHeartAttacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1319 non-null   int64
#  1   Gender                    1319 non-null   int64
#  2   Heart rate                1319 non-null   int64
#  3   Systolic blood pressure   1319 non-null   int64
#  4   Diastolic blood pressure  1319 non-null   int64
#  5   Blood sugar               1319 non-null   float64
#  6   CK-MB                     1319 non-null   float64
#  7   Troponin                  1319 non-null   float64
#  8   Result                    1319 non-null   object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 92.9+ KB

# %%
# Output only the header to have an overview of the data 
dataHeartAttacks.head()
# Out:
#    Age  Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   64       1          66                      160                        83
# 1   21       1          94                       98                        46
# 2   55       1          64                      160                        77
# 3   64       1          70                      120                        55
# 4   55       1          64                      112                        65
#
#    Blood sugar  CK-MB  Troponin    Result
# 0        160.0   1.80     0.012  negative
# 1        296.0   6.75     1.060  positive
# 2        270.0   1.99     0.003  negative
# 3        270.0  13.87     0.122  positive
# 4        300.0   1.08     0.003  negative

# %% [raw]
# As we can see on the on the header we have 9 columns with information of the patients such as age, gender, heart rate etc. We will use this information to predict how likely is for a patient to have a heart attack.
# We will break our data in train and test sets to test the models we will be creating.
# Data looks pretty randomized but we will do it just in case

# %%
train_df, test_df = train_test_split(
    dataHeartAttacks,      # dataset
    test_size=0.20,        # 20 % testing → 80 % training
    shuffle=True,          # randomize the data True 
    random_state=42,       # seed for repeatable results
    stratify= dataHeartAttacks["Result"]       # stratify the Result columns to balance classes
)

# %%
train_df.head()
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 881    54       1          63                      105
# 723    36       0          59                      137
# 889    65       1          77                      122
# 1004   72       0          94                      122
# 761    55       0          68                      116
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 881                         64        121.0  11.94     0.005  positive
# 723                         81         99.0   4.15     0.003  negative
# 889                         58        106.0   1.57     0.484  positive
# 1004                        67        392.0   1.09     0.016  positive
# 761                         74        143.0   1.34     0.094  positive

# %%
test_df.head()
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 1295   64       0          68                       91
# 139    43       0          79                       89
# 160    82       1          62                      126
# 1184   34       0          81                      125
# 474    41       1          86                      113
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 1295                        61        119.0   2.97     1.530  positive
# 139                         57         98.0   2.46     0.006  negative
# 160                         65        137.0  39.53     0.006  positive
# 1184                        69        152.0   2.07     0.013  negative
# 474                         68        100.0   4.58     0.003  negative

# %% [raw]
# Now that we have randomized and divided the data.
# We will plot the train data to visualize and understand the patterns in it.

# %%
# Convert the Result column in binary values 0 for negative and 1 for positive
train_df["Result"] = train_df["Result"].map({"negative": 0, "positive": 1})
train_df.head()
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 881    54       1          63                      105
# 723    36       0          59                      137
# 889    65       1          77                      122
# 1004   72       0          94                      122
# 761    55       0          68                      116
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin  Result
# 881                         64        121.0  11.94     0.005       1
# 723                         81         99.0   4.15     0.003       0
# 889                         58        106.0   1.57     0.484       1
# 1004                        67        392.0   1.09     0.016       1
# 761                         74        143.0   1.34     0.094       1

# %%
# Do the same for the test dataframe
test_df["Result"] = test_df["Result"].map({"negative": 0, "positive": 1})
test_df.head()
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 1295   64       0          68                       91
# 139    43       0          79                       89
# 160    82       1          62                      126
# 1184   34       0          81                      125
# 474    41       1          86                      113
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin  Result
# 1295                        61        119.0   2.97     1.530       1
# 139                         57         98.0   2.46     0.006       0
# 160                         65        137.0  39.53     0.006       1
# 1184                        69        152.0   2.07     0.013       0
# 474                         68        100.0   4.58     0.003       0

# %%
# Plot only the Age and Result column

test_df[0:10].plot(x='Age', y='Result', kind='scatter')
plt.title('Line Plot of X_values vs Y_values')
plt.xlabel('Age')
plt.ylabel('Heart Atack')
plt.grid(True)
plt.show()
